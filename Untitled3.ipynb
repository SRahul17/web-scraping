# %%
#importing libraries

import pandas as pd
import selenium
from selenium import webdriver
import time
import re
import requests
from selenium.common.exceptions import NoSuchElementException

import warnings
warnings.filterwarnings("ignore")

# %%
# driver initialization
driver=webdriver.Chrome(r'C:\Users\rahul\Downloads\chromedriver_win32\chromedriver.exe')

# %%
# browsing url

url="https://www.demandstar.com/app/agencies/california/city-of-sunnyvale/procurement-opportunities/e9a860f4-8f17-43af-aae7-e5dc8389f36e/"
#locationCromedriver="C:\Users\rahul\Downloads\chromedriver_win32\chromedriver.exe"

class scrapper:
    def testMethod(self):
        #driver=webdriver.Chrome(r'locationCromedriver')
        driver.get(url) 
        
        
        
obj=scrapper()
obj.testMethod()

# %%
#scrapping the data

Tender_name=[]
Location=[]
ID=[]
Due_date=[]
Broadcast_date=[]
Planholders=[]
Status=[]


for i in driver.find_elements_by_xpath('//a[@class="mw-75 text-truncate"]'):
    Tender_name.append(i.text)

for j in driver.find_elements_by_xpath('//div[@class="listGroupWrapper clearfix"]/p'):
    Location.append(j.text)

for k in driver.find_elements_by_xpath('//ul[@class="list-inline"]/li[1]'):
    ID.append(k.text.replace("ID:"," "))
    
for l in driver.find_elements_by_xpath('//ul[@class="list-inline"]/li[4]'):
    Planholders.append(l.text.replace("#Planholders:"," "))
    
for m in driver.find_elements_by_xpath('//ul[@class="list-inline"]/li[2]'):
    Due_date.append(m.text.replace("Due:"," "))

for n in driver.find_elements_by_xpath('//ul[@class="list-inline"]/li[3]'):
    Broadcast_date.append(n.text.replace("Broadcast:"," "))

for p in driver.find_elements_by_xpath('//h5[@class="mw-100 text-truncate"]/span'):
    Status.append(p.text)


        
print(len(Tender_name))
print(len(Location))
print(len(ID))
print(len(Planholders))
print(len(Due_date))
print(len(Broadcast_date))
print(len(Status))
# Out:
# 100
# 100
# 100
# 100
# 100
# 100
# 100

# %%
#making the dataframe of data
df = pd.DataFrame({})
df["Tender_name"] = Tender_name
df["Location"] = Location
df["ID"] = ID
df["Planholders"] = Planholders
df["Due_date"] = Due_date
df["Broadcast_date"] = Broadcast_date
df["Status"] = Status
df
# Out:
#                                           Tender_name  \
# 0               Polymer, Coagulant/Floculant Products
# 1                             Annual Slurry Seal 2022
# 2                         Network Appliance Equipment
# 3   Concrete Sidewalk, Curb, Gutter and Driveway A...
# 4   Professional Services for Safety and Loss Control
# ..                                                ...
# 95                 Street Light Poles and Accessories
# 96                            Annual Slurry Seal 2020
# 97  On-Call Fire Protection & Building Safety Revi...
# 98           Comprehensive Development User Fee Study
# 99  Concrete Sidewalk, Curb, Gutter, Driveway Repl...
#
#                             Location                        ID Planholders  \
# 0   City of Sunnyvale, Sunnyvale, CA    RFQL-F22-095-0-2022/LV          15
# 1   City of Sunnyvale, Sunnyvale, CA     IFB-PW22-06-0-2022/LV           6
# 2   City of Sunnyvale, Sunnyvale, CA    IFB-F22-089-0-2022/MAP           9
# 3   City of Sunnyvale, Sunnyvale, CA     IFB-PW22-07-0-2022/LV          12
# 4   City of Sunnyvale, Sunnyvale, CA     RFP-F22-064-0-2022/LV          10
# ..                               ...                       ...         ...
# 95  City of Sunnyvale, Sunnyvale, CA     IFB-F19-223-0-2020/IC          18
# 96  City of Sunnyvale, Sunnyvale, CA     IFB-PW20-13-0-2020/LV          19
# 97  City of Sunnyvale, Sunnyvale, CA    RFP-F19-235-0-2020/JLe          22
# 98  City of Sunnyvale, Sunnyvale, CA    RFP-F20-066-0-2020/JLe          11
# 99  City of Sunnyvale, Sunnyvale, CA    IFB-PW20-07-0-2020/JLe          20
#
#         Due_date Broadcast_date   Status
# 0     06/16/2022     03/23/2022   Active
# 1     04/27/2022     04/01/2022   Active
# 2     04/13/2022     03/28/2022   Active
# 3     04/13/2022     03/25/2022   Active
# 4     04/05/2022     03/02/2022   Active
# ..           ...            ...      ...
# 95    02/05/2020     01/08/2020  Awarded
# 96    01/29/2020     01/02/2020  Awarded
# 97    01/10/2020     12/05/2019  Awarded
# 98    12/13/2019     11/15/2019  Awarded
# 99    12/11/2019     11/21/2019  Awarded
#
# [100 rows x 7 columns]

# %%
df.to_csv('tender_of_City_Sunnyvale.csv') # saving to csv file

# %%
df1=pd.read_csv("tender_of_City_Sunnyvale.csv")
df1
# Out:
#     Unnamed: 0                                        Tender_name  \
# 0            0              Polymer, Coagulant/Floculant Products
# 1            1                            Annual Slurry Seal 2022
# 2            2                        Network Appliance Equipment
# 3            3  Concrete Sidewalk, Curb, Gutter and Driveway A...
# 4            4  Professional Services for Safety and Loss Control
# ..         ...                                                ...
# 95          95                 Street Light Poles and Accessories
# 96          96                            Annual Slurry Seal 2020
# 97          97  On-Call Fire Protection & Building Safety Revi...
# 98          98           Comprehensive Development User Fee Study
# 99          99  Concrete Sidewalk, Curb, Gutter, Driveway Repl...
#
#                             Location                        ID  Planholders  \
# 0   City of Sunnyvale, Sunnyvale, CA    RFQL-F22-095-0-2022/LV           15
# 1   City of Sunnyvale, Sunnyvale, CA     IFB-PW22-06-0-2022/LV            6
# 2   City of Sunnyvale, Sunnyvale, CA    IFB-F22-089-0-2022/MAP            9
# 3   City of Sunnyvale, Sunnyvale, CA     IFB-PW22-07-0-2022/LV           12
# 4   City of Sunnyvale, Sunnyvale, CA     RFP-F22-064-0-2022/LV           10
# ..                               ...                       ...          ...
# 95  City of Sunnyvale, Sunnyvale, CA     IFB-F19-223-0-2020/IC           18
# 96  City of Sunnyvale, Sunnyvale, CA     IFB-PW20-13-0-2020/LV           19
# 97  City of Sunnyvale, Sunnyvale, CA    RFP-F19-235-0-2020/JLe           22
# 98  City of Sunnyvale, Sunnyvale, CA    RFP-F20-066-0-2020/JLe           11
# 99  City of Sunnyvale, Sunnyvale, CA    IFB-PW20-07-0-2020/JLe           20
#
#         Due_date Broadcast_date   Status
# 0     06/16/2022     03/23/2022   Active
# 1     04/27/2022     04/01/2022   Active
# 2     04/13/2022     03/28/2022   Active
# 3     04/13/2022     03/25/2022   Active
# 4     04/05/2022     03/02/2022   Active
# ..           ...            ...      ...
# 95    02/05/2020     01/08/2020  Awarded
# 96    01/29/2020     01/02/2020  Awarded
# 97    01/10/2020     12/05/2019  Awarded
# 98    12/13/2019     11/15/2019  Awarded
# 99    12/11/2019     11/21/2019  Awarded
#
# [100 rows x 8 columns]

# %%
driver.quit()

# %%
driver=webdriver.Chrome(r'C:\Users\rahul\Downloads\chromedriver_win32\chromedriver.exe')

# %%
url="https://www.contractsfinder.service.gov.uk/Search/Results"
#locationCromedriver="C:\Users\lenovo\Downloads\chromedriver_win32 (5)\chromedriver.exe"

class scrapper:
    def testMethod(self):
        #driver=webdriver.Chrome(r'locationCromedriver')
        driver.get(url) 
        
        
        
obj=scrapper()
obj.testMethod()

# %%
Tender_name=[]
Company_name=[]
Procurement_stage=[]
Notice_status=[]
Closing=[]
Contract_location=[]
Contract_value=[]
Publication_date=[]

# %%
def calling_fun():
    for i in driver.find_elements_by_xpath('//a[@class="govuk-link search-result-rwh break-word"]'):
        Tender_name.append(i.text)

    for j in driver.find_elements_by_xpath('//div[@class="search-result-sub-header wrap-text"]'):
        Company_name.append(j.text)

    for k in driver.find_elements_by_xpath('//div[@class="search-result-entry"][1]'):
        Procurement_stage.append(k.text.replace("Procurement stage"," "))
    
    for l in driver.find_elements_by_xpath('//div[@class="search-result-entry"][2]'):
        Notice_status.append(l.text.replace("Notice status"," "))
    
    for m in driver.find_elements_by_xpath('//div[@class="search-result-entry"][3]'):
        Closing.append(m.text.replace("Closing"," "))

    for n in driver.find_elements_by_xpath('//div[@class="search-result-entry"][4]'):
        Contract_location.append(n.text.replace("Contract location"," "))

    for o in driver.find_elements_by_xpath('//div[@class="search-result-entry"][5]'):
        try:
            Contract_value.append(o.text.replace("Contract value"," "))
        except:
            Contract_value.append("--")
    
    for p in driver.find_elements_by_xpath('//div[@class="search-result-entry"][6]'):
        try:
            Publication_date.append(p.text.replace("Publication date"," "))
        except:
            Publication_date.append("--")


        
    print(len(Tender_name))
    print(len(Company_name))
    print(len(Procurement_stage))
    print(len(Notice_status))
    print(len(Closing))
    print(len(Contract_location))
    print(len(Contract_value))
    print(len(Publication_date))

# %%
calling_fun()
# Out:
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 19

# %%
Publication_date.append("--")

# %%
varbutton = driver.find_element_by_xpath('//li[@class="standard-paginate "]/a[1]')
varbutton
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="00c1c355cbf9e7c769f91a0053d13013", element="66a3e47b-ad67-4e4a-8fde-eacf6edecb7e")>

# %%
varbutton = driver.find_element_by_xpath('//ul[@class="gadget-footer-paginate"]/li[4]/a')
varbutton
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="00c1c355cbf9e7c769f91a0053d13013", element="b6c49990-9e1e-4b87-bb9f-7ae405555bd3")>

# %%
df = pd.DataFrame({})
df["Tender_name"] = Tender_name
df["Company_name"] = Company_name
df["Procurement_stage"] = Procurement_stage
df["Notice_status"] = Notice_status
df["Closing"] = Closing
df["Contract_location"] = Contract_location
df["Contract_value"] = Contract_value
df["Publication_date"] = Publication_date
df
# Out:
#                                           Tender_name  \
# 0   Grass and Hedge Cutting at properties included...
# 1                   Customer Service Advisor KB010422
# 2                      YPO - 001109 - Office Machines
# 3   Llanthony Road (Gloucester South West Bypass) ...
# 4   Capability Assessment for the provision of Res...
# 5                      Recruitment Services Framework
# 6   Mental Health Accommodation in North-East & We...
# 7                   Procurement of Construction Works
# 8                        Energy Procurement Framework
# 9   "Everything ICT" - full range of ICT Products,...
# 10                        35 Eastgate Preston PR2 3HS
# 11                                   CCTV Maintenance
# 12  Graduation and Ceremonial gowns, Photography a...
# 13                      Placement Management Solution
# 14      DAPL Reopening - Healthcare Services - i-1428
# 15     DAPL Reopening - Primary Care Services - i1429
# 16               Artificial Grass Pitch Refurbishment
# 17           AG21511 - Enhanced Mental Health Service
# 18                      Innovation Talent Development
# 19             A38 Bromsgrove Road Enhancement Scheme
#
#                                          Company_name   Procurement_stage  \
# 0                           Grand Union Housing Group         Opportunity
# 1               Sandwell Metropolitan Borough Council         Opportunity
# 2                                                 YPO         Opportunity
# 3                      Gloucestershire County Council         Opportunity
# 4                             Valuation Office Agency    Early engagement
# 5     CTM Portal for the NDA Shared Services Alliance         Opportunity
# 6                                Essex County Council         Opportunity
# 7                      Loughborough Bellfoundry Trust         Opportunity
# 8                        Cirrus Primary Academy Trust         Opportunity
# 9   East of England Broadband Network (Regional Br...         Opportunity
# 10                             Progress Housing Group         Opportunity
# 11                                 Northumbria Police         Opportunity
# 12          London Universities Purchasing Consortium         Opportunity
# 13             University of Huddersfield e-Tendering         Opportunity
# 14                         Oxfordshire County Council         Opportunity
# 15                         Oxfordshire County Council         Opportunity
# 16                           Leeds Trinity University         Opportunity
# 17  NHS Arden and Greater East Midlands Commission...         Opportunity
# 18                                        NHS England         Opportunity
# 19                      Worcestershire County Council         Opportunity
#
#    Notice_status                Closing           Contract_location  \
# 0           Open       9 May 2022, 12pm                     MK7 6BZ
# 1           Open     6 April 2022, 12pm                     B70 8SZ
# 2           Open       13 May 2022, 2pm              United Kingdom
# 3           Open       5 May 2022, 12pm                     England
# 4           Open          12 April 2022              United Kingdom
# 5           Open     15 April 2022, 4pm                  Any region
# 6           Open      13 May 2022, 12pm              United Kingdom
# 7           Open      16 May 2022, 12pm               East Midlands
# 8           Open       4 May 2022, 12pm          Any region, London
# 9           Open      11 May 2022, 12pm                  Any region
# 10          Open       6 May 2022, 12pm                     PR2 3HS
# 11          Open    29 April 2022, 12pm                  North East
# 12          Open        5 May 2022, 5pm                  Any region
# 13          Open      20 May 2022, 12pm                     HD1 3DH
# 14          Open    31 March 2026, 12pm                     England
# 15          Open    31 March 2026, 12pm                     England
# 16          Open        3 May 2022, 1pm    Yorkshire and the Humber
# 17          Open        6 May 2022, 3pm             East of England
# 18          Open       4 May 2022, 12pm                     LS2 7UE
# 19          Open       3 May 2022, 12pm                     WR5 2NP
#
#                                        Contract_value Publication_date
# 0                                                  £0     2 April 2022
# 1                                           £4,808.52     1 April 2022
# 2                                    £0 to £4,000,000     1 April 2022
# 3                                    £0 to £3,250,000     1 April 2022
# 4   Publication date 1 April 2022, last edited 1 A...     1 April 2022
# 5                                    £1 to £1,000,000     1 April 2022
# 6                                         £15,500,000     1 April 2022
# 7                                                  £0     1 April 2022
# 8                                                  £0     1 April 2022
# 9                                                  £0     1 April 2022
# 10                                            £81,000     1 April 2022
# 11                                £80,000 to £110,000     1 April 2022
# 12                                  £0 to £16,000,000     1 April 2022
# 13                               £150,000 to £600,000     1 April 2022
# 14                                         £1,275,000     1 April 2022
# 15                                         £1,475,000     1 April 2022
# 16                                           £300,000     1 April 2022
# 17                                   £0 to £1,425,000     1 April 2022
# 18                                           £145,000     1 April 2022
# 19                                  £0 to £35,000,000               --

# %%
df.to_csv("UK_contracts.csv")

# %%
driver.quit()
